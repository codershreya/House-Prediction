# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
data_frame = pd.read_csv("Housing.csv")
data_frame
# Out:
#         price  area  bedrooms  bathrooms  stories mainroad guestroom basement  \
# 0    13300000  7420         4          2        3      yes        no       no
# 1    12250000  8960         4          4        4      yes        no       no
# 2    12250000  9960         3          2        2      yes        no      yes
# 3    12215000  7500         4          2        2      yes        no      yes
# 4    11410000  7420         4          1        2      yes       yes      yes
# ..        ...   ...       ...        ...      ...      ...       ...      ...
# 540   1820000  3000         2          1        1      yes        no      yes
# 541   1767150  2400         3          1        1       no        no       no
# 542   1750000  3620         2          1        1      yes        no       no
# 543   1750000  2910         3          1        1       no        no       no
# 544   1750000  3850         3          1        2      yes        no       no
#
# ...

# %%
data_frame.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 545 entries, 0 to 544
# Data columns (total 13 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   price             545 non-null    int64
#  1   area              545 non-null    int64
#  2   bedrooms          545 non-null    int64
#  3   bathrooms         545 non-null    int64
#  4   stories           545 non-null    int64
#  5   mainroad          545 non-null    object
#  6   guestroom         545 non-null    object
#  7   basement          545 non-null    object
#  8   hotwaterheating   545 non-null    object
#  9   airconditioning   545 non-null    object
#  10  parking           545 non-null    int64
#  11  prefarea          545 non-null    object
#  12  furnishingstatus  545 non-null    object
# dtypes: int64(6), object(7)
# memory usage: 55.5+ KB

# %%
data_frame.isnull().sum()
# Out:
# price               0
# area                0
# bedrooms            0
# bathrooms           0
# stories             0
# mainroad            0
# guestroom           0
# basement            0
# hotwaterheating     0
# airconditioning     0
# parking             0
# prefarea            0
# furnishingstatus    0
# dtype: int64

# %%
data_frame.replace({"yes":1 , "no":0},inplace=True)
data_frame
# Out:
#         price  area  bedrooms  bathrooms  stories  mainroad  guestroom  \
# 0    13300000  7420         4          2        3         1          0
# 1    12250000  8960         4          4        4         1          0
# 2    12250000  9960         3          2        2         1          0
# 3    12215000  7500         4          2        2         1          0
# 4    11410000  7420         4          1        2         1          1
# ..        ...   ...       ...        ...      ...       ...        ...
# 540   1820000  3000         2          1        1         1          0
# 541   1767150  2400         3          1        1         0          0
# 542   1750000  3620         2          1        1         1          0
# 543   1750000  2910         3          1        1         0          0
# 544   1750000  3850         3          1        2         1          0
#
#      basement  hotwaterheating  airconditioning  parking  prefarea  \
# ...

# %%
data_frame.describe()
# Out:
#               price          area    bedrooms   bathrooms     stories  \
# count  5.450000e+02    545.000000  545.000000  545.000000  545.000000
# mean   4.766729e+06   5150.541284    2.965138    1.286239    1.805505
# std    1.870440e+06   2170.141023    0.738064    0.502470    0.867492
# min    1.750000e+06   1650.000000    1.000000    1.000000    1.000000
# 25%    3.430000e+06   3600.000000    2.000000    1.000000    1.000000
# 50%    4.340000e+06   4600.000000    3.000000    1.000000    2.000000
# 75%    5.740000e+06   6360.000000    3.000000    2.000000    2.000000
# max    1.330000e+07  16200.000000    6.000000    4.000000    4.000000
#
#          mainroad   guestroom    basement  hotwaterheating  airconditioning  \
# count  545.000000  545.000000  545.000000       545.000000       545.000000
# mean     0.858716    0.177982    0.350459         0.045872         0.315596
# std      0.348635    0.382849    0.477552         0.209399         0.465180
# ...

# %%
plt.figure(figsize = (5,5))
plt.scatter (data_frame["parking"],data_frame["price"],alpha= 0.3)
plt.xlabel("House Parking")
plt.ylabel("House Price")
plt.show()

# %%
num_values = ["area", "bedrooms","bathrooms","stories","parking"]
data_frame[num_values].corr()
# Out:
#                area  bedrooms  bathrooms   stories   parking
# area       1.000000  0.151858   0.193820  0.083996  0.352980
# bedrooms   0.151858  1.000000   0.373930  0.408564  0.139270
# bathrooms  0.193820  0.373930   1.000000  0.326165  0.177496
# stories    0.083996  0.408564   0.326165  1.000000  0.045547
# parking    0.352980  0.139270   0.177496  0.045547  1.000000

# %%
new = data_frame.groupby("bedrooms")[["price"]].agg({"price":"median"})
new
# Out:
#               price
# bedrooms
# 1         2712500.0
# 2         3535000.0
# 3         4620000.0
# 4         5250000.0
# 5         5582500.0
# 6         4791500.0

# %%
# theta_1 = ((np.mean(new.index)-new.index)*(new["price"].mean()-new["price"])).sum() / ((np.mean(new.index)-new.index)**2).sum()
# theta_0 = new["price"].mean() - (theta_1*np.mean(new.index))
theta_1 = ((np.mean(new.index)-new.index)*(new["price"].mean()-new["price"])).sum() / ((new["price"].mean()-new["price"])**2).sum()
theta_0 = np.mean(new.index) - (theta_1*new["price"].mean())
theta_1, theta_0
# Out:
# (1.4507016530752732e-06, -2.9052104737406)

# %%
y_hat = theta_0 + theta_1*new["price"]
y_hat
# Out:
# bedrooms
# 1    1.029818
# 2    2.223020
# 3    3.797031
# 4    4.710973
# 5    5.193332
# 6    4.045826
# Name: price, dtype: float64

# %%
new.index
# Out:
# Index([1, 2, 3, 4, 5, 6], dtype='int64', name='bedrooms')

# %%
new['price']
# Out:
# bedrooms
# 1    2712500.0
# 2    3535000.0
# 3    4620000.0
# 4    5250000.0
# 5    5582500.0
# 6    4791500.0
# Name: price, dtype: float64

# %%
r = np.corrcoef(new.index, new["price"])[0,1]
r
# Out:
# 0.8435455890664247

# %%
plt.scatter(new, new.index, alpha=0.9, label=f"r = {r:0.2f}")
plt.plot(new['price'], y_hat, color="red", label="Mean Prediction")
plt.xlabel("Price of House's")
plt.ylabel("No.of Bedrooms")
plt.legend(loc=2)
plt.title("Bedroom vs House Price")
plt.show()

# %%
fig, ((ax1,ax2),(ax3,ax4),(ax5,ax6)) = plt.subplots(nrows=3, ncols=2, figsize=(20, 20), dpi=500)
                                            
seq = zip(
        ["area","bedrooms","bathrooms","parking","stories","mainroad"],
        [ax1   ,   ax2    ,    ax3  ,  ax4     ,    ax5   ,  ax6])
   
for column , ax in seq:
        r = np.corrcoef(data_frame[column], data_frame["price"])[0, 1]
        ax.plot(data_frame[column], data_frame["price"], "bo", label = f"r = {r:0.2f}", mfc='white', alpha=0.5)
        ax.set_title(f"{column} vs Price")
        ax.set_xlabel(column)
        ax.set_ylabel("price")
        ax.legend()
        
plt.show()

# %%
data_frame.groupby ("hotwaterheating")[["hotwaterheating"]].count().plot(kind="pie",autopct="%0.2f%%",subplots = True)
plt.show()

# %%
data_frame
# Out:
#         price  area  bedrooms  bathrooms  stories  mainroad  guestroom  \
# 0    13300000  7420         4          2        3         1          0
# 1    12250000  8960         4          4        4         1          0
# 2    12250000  9960         3          2        2         1          0
# 3    12215000  7500         4          2        2         1          0
# 4    11410000  7420         4          1        2         1          1
# ..        ...   ...       ...        ...      ...       ...        ...
# 540   1820000  3000         2          1        1         1          0
# 541   1767150  2400         3          1        1         0          0
# 542   1750000  3620         2          1        1         1          0
# 543   1750000  2910         3          1        1         0          0
# 544   1750000  3850         3          1        2         1          0
#
#      basement  hotwaterheating  airconditioning  parking  prefarea  \
# ...

# %%
data_frame.groupby("hotwaterheating")[["hotwaterheating","price"]].agg({"hotwaterheating":"count","price": "mean"}).plot(kind="bar")
plt.show()

# %%
data_frame.groupby("airconditioning")[["airconditioning"]].count().plot(kind="pie",autopct="%0.2f%%",subplots = True)
plt.show()

# %%
data_frame.groupby("airconditioning")[["airconditioning","price"]].agg({"airconditioning":"count","price": "mean"}).plot(kind="bar")
plt.show()

# %%
data_frame.groupby("parking")[["price"]].median().plot()
plt.ylabel("House Prices (in ten-lakhs)")
# data_frame.groupby("bathrooms")[["price"]].median()
# Out:
# Text(0, 0.5, 'House Prices (in ten-lakhs)')

# %%
data_frame.groupby("bedrooms")[["price"]].median().plot()
plt.ylabel("House Price (in ten-lakhs)")
# Out:
# Text(0, 0.5, 'House Price (in ten-lakhs)')

# %%
X = data_frame.drop('price',axis =1)
y = data_frame['price']

# %%
X.head()
# Out:
#    area  bedrooms  bathrooms  stories  mainroad  guestroom  basement  \
# 0  7420         4          2        3         1          0         0
# 1  8960         4          4        4         1          0         0
# 2  9960         3          2        2         1          0         1
# 3  7500         4          2        2         1          0         1
# 4  7420         4          1        2         1          1         1
#
#    hotwaterheating  airconditioning  parking  prefarea furnishingstatus
# 0                0                1        2         1        furnished
# 1                0                1        3         0        furnished
# 2                0                0        2         1   semi-furnished
# 3                0                1        3         1        furnished
# 4                0                1        2         0        furnished

# %%
y.head()
# Out:
# 0    13300000
# 1    12250000
# 2    12250000
# 3    12215000
# 4    11410000
# Name: price, dtype: int64

# %%
X.shape[0]*0.20
# Out:
# 109.0

# %%
from sklearn.model_selection import train_test_split 
X_train, X_test, y_train , y_test = train_test_split(X,y,random_state=45,test_size=0.15)

# %%
X_train.head()
# Out:
#      area  bedrooms  bathrooms  stories  mainroad  guestroom  basement  \
# 527  1836         2          1        1         0          0         1
# 39   6000         4          2        4         1          0         0
# 172  8400         3          1        2         1          1         1
# 145  5000         3          1        4         1          0         0
# 76   6420         3          2        3         1          0         0
#
#      hotwaterheating  airconditioning  parking  prefarea furnishingstatus
# 527                0                0        0         0   semi-furnished
# 39                 0                1        1         0   semi-furnished
# 172                0                1        2         1      unfurnished
# 145                0                0        0         0        furnished
# 76                 0                1        0         1        furnished

# %%
y_train.head()
# Out:
# 527    2275000
# 39     7910000
# 172    5250000
# 145    5600000
# 76     6650000
# Name: price, dtype: int64

# %%
X_test.head()
# Out:
#      area  bedrooms  bathrooms  stories  mainroad  guestroom  basement  \
# 510  2880         3          1        1         0          0         0
# 179  3180         3          2        2         1          0         0
# 482  3150         3          1        2         0          0         0
# 342  7152         3          1        2         1          0         0
# 491  2640         2          1        1         0          0         0
#
#      hotwaterheating  airconditioning  parking  prefarea furnishingstatus
# 510                0                0        0         0      unfurnished
# 179                0                0        2         0   semi-furnished
# 482                0                0        0         0      unfurnished
# 342                0                1        0         0        furnished
# 491                0                0        1         0        furnished

# %%
y_test.head()
# Out:
# 510    2520000
# 179    5215000
# 482    2940000
# 342    3850000
# 491    2835000
# Name: price, dtype: int64

# %%
X_train.corrwith(y_train, numeric_only=True)
# Out:
# area               0.552620
# bedrooms           0.352927
# bathrooms          0.534521
# stories            0.414653
# mainroad           0.298591
# guestroom          0.245029
# basement           0.180797
# hotwaterheating    0.074685
# airconditioning    0.465286
# parking            0.382593
# prefarea           0.325188
# dtype: float64

# %%
from sklearn.impute import SimpleImputer
from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import OneHotEncoder
from sklearn.preprocessing import OrdinalEncoder

from sklearn.pipeline import Pipeline 
from sklearn.compose import ColumnTransformer

from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error
from sklearn.metrics import r2_score

def rmse(y,y_hat):
    return np.sqrt(mean_squared_error(y,y_hat))

# %%
num_values = ['area','bedrooms', 'bathrooms', 'stories', 'mainroad', 'airconditioning']
nom_values = ['furnishingstatus']

# %%
pipeline = ColumnTransformer([
    ('numerical pipeline', numerical_pipeline, num_values), # bedrooms, bathrooms, stories, mainroad, airconditioning, prefarea
    ('nominal pipeline', nominal_pipeline, nom_values) # furnished, semi-furnished, unfurnished.
])
output_cols = ['area', 'bedrooms', 'bathrooms', 'stories', 'mainroad', 'airconditioning',
               'furnished', 'semi-furnished', 'unfurnished']
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 pipeline = ColumnTransformer([
#       2     ('numerical pipeline', numerical_pipeline, num_values), # bedrooms, bathrooms, stories, mainroad, airconditioning, prefarea
#       3     ('nominal pipeline', nominal_pipeline, nom_values) # furnished, semi-furnished, unfurnished.
#       4 ])
#       5 output_cols = ['area', 'bedrooms', 'bathrooms', 'stories', 'mainroad', 'airconditioning',
#       6                'furnished', 'semi-furnished', 'unfurnished']
#
# NameError: name 'ColumnTransformer' is not defined
